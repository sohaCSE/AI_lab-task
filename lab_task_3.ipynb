# %% [markdown]
# <a href="https://colab.research.google.com/github/sohaCSE/AI_lab-task/blob/main/lab_task_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data = []
choice = 'random'

def line():
    print('---------------------------')

def show_menu():
    line()
    print('MENU')
    line()
    print('1. Add courses')
    print('2. Remove or Unenroll a course')
    print('3. View courses')
    print('4. Exit')
    line()
    choice = input('Enter your choice: ')
    return choice

while choice != '4':
    choice = show_menu()
    if choice == '1':
        item = input('Add course name to enroll ')
        data.append(item)
        print('Course ', item, 'added')
    elif choice == '2':
        item = input('which course do you want to unenroll? ')
        if item in data:
            data.remove(item)
            print('You have been unenroll from the course', item)
        else:
            print('Could not find the course name', item)
    elif choice == '3':
        print('List of my courses:')
        for item in data:
            print(item)
    elif choice == '4':
        print('Goodbye!')
    else:
        print('Please enter one of 1, 2, 3 or 4')
# Out:
# ---------------------------
# MENU
# ---------------------------
# 1. Add courses
# 2. Remove or Unenroll a course
# 3. View courses
# 4. Exit
# ---------------------------
# Enter your choice: 1
# Add course name to enroll Math
# Course  Math  added
# ---------------------------
# MENU
# ---------------------------
# 1. Add courses
# 2. Remove or Unenroll a course
# 3. View courses
# 4. Exit
# ---------------------------
# Enter your choice: 1
# Add course name to enroll English
# Course  English added
# ---------------------------
# MENU
# ---------------------------
# 1. Add courses
# 2. Remove or Unenroll a course
# 3. View courses
# 4. Exit
# ---------------------------
# Enter your choice: 1
# Add course name to enroll Bangla
# Course  Bangla added
# ---------------------------
# MENU
# ---------------------------
# 1. Add courses
# 2. Remove or Unenroll a course
# 3. View courses
# 4. Exit
# ---------------------------
# Enter your choice: 3
# List of my courses:
# Math
# English
# Bangla
# ---------------------------
# MENU
# ---------------------------
# 1. Add courses
# 2. Remove or Unenroll a course
# 3. View courses
# 4. Exit
# ---------------------------
# Enter your choice: 2
# which course do you want to unenroll? English
# You have been unenroll from the course English
# ---------------------------
# MENU
# ---------------------------
# 1. Add courses
# 2. Remove or Unenroll a course
# 3. View courses
# 4. Exit
# ---------------------------
# Enter your choice: 3
# List of my courses:
# Math
# Bangla
# ---------------------------
# MENU
# ---------------------------
# 1. Add courses
# 2. Remove or Unenroll a course
# 3. View courses
# 4. Exit
# ---------------------------
# Enter your choice: 4
# Goodbye!
